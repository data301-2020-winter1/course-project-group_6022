# %%
#lets start with the fact that if you want a quick and dirty data analysis.... pandas profiling is your best friend. 
import pandas as pd
import numpy as np
import pandas_profiling
from pandas_profiling import ProfileReport
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from scripts import project_functions as sc
path = "C:\\Users\\matta\\Documents\\UBCO 20-21\\Data 301\\course-project-group_6022\\data\\raw\\COVID19 cases Toronto.csv"
#Dear TA. the pandas profiling is in this folder. Please check it. 
df = sc.load_and_process(path)
#prof = ProfileReport(df)
#prof.to_file(output_file='profileReport.html')
#now we wait 10 years......
df
# Out:
#        Outbreak Associated       Age Group            Neighbourhood Name  FSA  \
# 0                 Sporadic           50-59               Willowdale East  M2N
# 1                 Sporadic           50-59               Willowdale East  M2N
# 2                 Sporadic           20-29             Parkwoods-Donalda  M3A
# 3      Outbreak Associated           50-59                     Moss Park  M5A
# 4                 Sporadic           70-79            Don Valley Village  M2J
# ...                    ...             ...                           ...  ...
# 13212             Sporadic           60-69                    Henry Farm  M2J
# 13213             Sporadic  19 and younger                    Maple Leaf  M6L
# 13214             Sporadic           30-39                    L'Amoreaux  M1W
# 13215             Sporadic           30-39  Thistletown-Beaumond Heights  M9V
# 13216             Sporadic           50-59        Tam O'Shanter-Sullivan  M1T
#
#              Source of Infection Episode Date Reported Date     Sex   Outcome  \
# 0                         Travel   2020-01-21    2020-01-23    MALE  RESOLVED
# 1                         Travel   2020-01-22    2020-01-23  FEMALE  RESOLVED
# 2                         Travel   2020-02-05    2020-02-21  FEMALE  RESOLVED
# 3      N/A - Outbreak associated   2020-02-07    2020-04-13    MALE  RESOLVED
# 4                         Travel   2020-02-14    2020-03-01  FEMALE  RESOLVED
# ...                          ...          ...           ...     ...       ...
# 13212              Close contact   2020-07-12    2020-06-28  FEMALE  RESOLVED
# 13213              Close contact   2020-07-12    2020-07-12  FEMALE    ACTIVE
# 13214              Close contact   2020-07-12    2020-07-12    MALE    ACTIVE
# 13215                     Travel   2020-07-12    2020-07-12    MALE    ACTIVE
# 13216            Unknown/Missing   2020-07-13    2020-07-13  FEMALE    ACTIVE
#
#       Currently Hospitalized Currently in ICU Currently Intubated  \
# 0                         No               No                  No
# 1                         No               No                  No
# 2                         No               No                  No
# 3                         No               No                  No
# 4                         No               No                  No
# ...                      ...              ...                 ...
# 13212                     No               No                  No
# 13213                     No               No                  No
# 13214                     No               No                  No
# 13215                     No               No                  No
# 13216                     No               No                  No
#
#       Ever Hospitalized Ever in ICU Ever Intubated
# 0                   Yes          No             No
# 1                    No          No             No
# 2                    No          No             No
# 3                    No          No             No
# 4                    No          No             No
# ...                 ...         ...            ...
# 13212                No          No             No
# 13213                No          No             No
# 13214                No          No             No
# 13215                No          No             No
# 13216                No          No             No
#
# [13217 rows x 15 columns]

# %%
#Lets apply the code we learned from lab four get a column called days_since
s_df = sc.simplify(sc.load_and_process(path))
s_df['Dt_Format'] = pd.to_datetime(s_df.Reported_Date)
s_df['Dt_Format'] = s_df.Dt_Format.dt.date
s_df['Days_Since'] = (s_df['Dt_Format'][0:] - min(s_df['Dt_Format'])) 
s_df['Days_Since'] = s_df['Days_Since'].dt.days
s_df
# Out:
#        Outbreak_Associated       Age_Group        Source_of_Infection  \
# 0                 Sporadic           50-59                     Travel
# 1                 Sporadic           50-59                     Travel
# 2                 Sporadic           20-29                     Travel
# 3      Outbreak Associated           50-59  N/A - Outbreak associated
# 4                 Sporadic           70-79                     Travel
# ...                    ...             ...                        ...
# 13212             Sporadic           60-69              Close contact
# 13213             Sporadic  19 and younger              Close contact
# 13214             Sporadic           30-39              Close contact
# 13215             Sporadic           30-39                     Travel
# 13216             Sporadic           50-59            Unknown/Missing
#
#       Episode_Date Reported_Date     Sex   Outcome Ever_Hospitalized  \
# 0       2020-01-21    2020-01-23    MALE  RESOLVED               Yes
# 1       2020-01-22    2020-01-23  FEMALE  RESOLVED                No
# 2       2020-02-05    2020-02-21  FEMALE  RESOLVED                No
# 3       2020-02-07    2020-04-13    MALE  RESOLVED                No
# 4       2020-02-14    2020-03-01  FEMALE  RESOLVED                No
# ...            ...           ...     ...       ...               ...
# 13212   2020-07-12    2020-06-28  FEMALE  RESOLVED                No
# 13213   2020-07-12    2020-07-12  FEMALE    ACTIVE                No
# 13214   2020-07-12    2020-07-12    MALE    ACTIVE                No
# 13215   2020-07-12    2020-07-12    MALE    ACTIVE                No
# 13216   2020-07-13    2020-07-13  FEMALE    ACTIVE                No
#
#       Ever_in_ICU Ever_Intubated   Dt_Format  Days_Since
# 0              No             No  2020-01-23           0
# 1              No             No  2020-01-23           0
# 2              No             No  2020-02-21          29
# 3              No             No  2020-04-13          81
# 4              No             No  2020-03-01          38
# ...           ...            ...         ...         ...
# 13212          No             No  2020-06-28         157
# 13213          No             No  2020-07-12         171
# 13214          No             No  2020-07-12         171
# 13215          No             No  2020-07-12         171
# 13216          No             No  2020-07-13         172
#
# [13217 rows x 12 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
#lets produce a fancy histogram of our age_group. unlike the lab this will require a little more finesse
ls = list(s_df.Age_Group.unique())

plt.figure(figsize=(15,5))

sns.set_theme(style="ticks", font_scale=1.3 ) # This scales the fonts slightly higher 
# And we're going to remove the top and right axis lines
plt.rc("axes.spines", top=False, right=False)

g = sns.histplot(data = s_df,   x = 'Days_Since', hue = 'Age_Group', multiple="dodge",  binwidth= 20)
plt.ylabel("Number of Reported Cases", size=15)
plt.title("Reported COVID-19 cases by Age")
plt.xlabel("Days since first reported case", size=15)
g.set(xlim=(0,175),ylim=(0,700))

plt.show()

print("The earliest reported case of COVID-19 in Ontario was: " + str(min(s_df['Dt_Format'])) )
print("The latest reported case of COVID-19 in Ontario was: "  + str(max(s_df['Dt_Format'])) )
# Out:
# The earliest reported case of COVID-19 in Ontario was: 2020-01-23
# The latest reported case of COVID-19 in Ontario was: 2020-07-13

# %%
plt.figure(figsize=(15,5))
sns.countplot(x= 'Sex', hue = "Age_Group", data=s_df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(y = "Source_of_Infection", data =s_df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Source_of_Infection'>
