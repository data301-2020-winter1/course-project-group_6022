# %%
import pandas as pd
import numpy as np
from scripts import project_functions as sc
import pandas_profiling
import seaborn as sns
#from pandas_profiling import ProfileReport
import sys, os
sys.path.insert(0, os.path.abspath('..'))
path = "D:\\Work\\DATA301\\course-project-group_6022\\data\\raw\\COVID19 cases Toronto.csv"
df = sc.load_and_process(path)
sns.countplot(x= 'Neighbourhood Name', hue = "Source of Infection", data=df)
# Out:
# <AxesSubplot:xlabel='Neighbourhood Name', ylabel='count'>
